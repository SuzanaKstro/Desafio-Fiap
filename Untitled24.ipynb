# %% [markdown]
# <a href="https://colab.research.google.com/github/SuzanaKstro/Desafio-Fiap/blob/main/Untitled24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# !pip install numpy pandas requests inflection seaborn scipy matplotlib IPython scikit-learn statsmodels pmdarima tqdm statsforecast
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 30.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.1/319.1 kB 23.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.6/275.6 kB 21.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 18.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 53.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.3/135.3 kB 11.9 MB/s eta 0:00:00
# ...

# %%
# !pip install inflection seaborn statsforecast pmdarima tqdm

# %%
df = pd.read_csv('/content/Dados Históricos - Ibovespa (2).csv')

# %%
df.head()
# Out:
#          Data   Último  Abertura   Máxima   Mínima    Vol.    Var%
# 0  30.12.2024  120.283   120.267  121.050  120.158   8,90M   0,01%
# 1  27.12.2024  120.269   121.078  121.609  120.252   8,94M  -0,67%
# 2  26.12.2024  121.078   120.767  121.612  120.428   8,34M   0,26%
# 3  23.12.2024  120.767   122.105  122.105  120.617   9,95M  -1,09%
# 4  20.12.2024  122.102   121.183  122.209  120.700  18,13M   0,75%

# %%
df['Data'] = pd.to_datetime(df['Data'], format="%d.%m.%Y")

# %%
df.tail()
# Out:
#            Data  Último  Abertura  Máxima  Mínima   Vol.    Var%
# 1488 2019-01-08  92.032    91.699  92.231  91.064  4,64M   0,36%
# 1489 2019-01-07  91.699    91.845  92.552  91.288  4,71M  -0,15%
# 1490 2019-01-04  91.841    91.577  92.701  90.824  5,49M   0,30%
# 1491 2019-01-03  91.564    91.011  91.596  89.922  6,25M   0,61%
# 1492 2019-01-02  91.012    87.887  91.479  87.536  5,79M   3,56%

# %%
df.isna().sum()
# Out:
# Data        0
# Último      0
# Abertura    0
# Máxima      0
# Mínima      0
# Vol.        0
# Var%        0
# dtype: int64

# %%
df.describe()
# Out:
#                                 Data       Último     Abertura       Máxima  \
# count                           1493  1493.000000  1493.000000  1493.000000
# mean   2022-01-01 14:07:47.782987008   111.406649   111.385396   112.355132
# min              2019-01-02 00:00:00    63.570000    63.604000    67.604000
# 25%              2020-07-03 00:00:00   102.675000   102.658000   103.780000
# 50%              2022-01-05 00:00:00   111.910000   111.897000   113.010000
# 75%              2023-07-04 00:00:00   120.283000   120.267000   121.252000
# max              2024-12-30 00:00:00   137.344000   137.349000   137.469000
# std                              NaN    12.829565    12.841659    12.634242
#
#             Mínima
# count  1493.000000
# mean    110.426958
# min      61.691000
# 25%     101.667000
# 50%     110.752000
# 75%     119.392000
# max     136.664000
# std      13.019710

# %%
df.dtypes
# Out:
# Data        datetime64[ns]
# Último             float64
# Abertura           float64
# Máxima             float64
# Mínima             float64
# Vol.                object
# Var%                object
# dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.tail()
# Out:
#            Data  Último  Abertura  Máxima  Mínima   Vol.    Var%
# 1488 2019-01-08  92.032    91.699  92.231  91.064  4,64M   0,36%
# 1489 2019-01-07  91.699    91.845  92.552  91.288  4,71M  -0,15%
# 1490 2019-01-04  91.841    91.577  92.701  90.824  5,49M   0,30%
# 1491 2019-01-03  91.564    91.011  91.596  89.922  6,25M   0,61%
# 1492 2019-01-02  91.012    87.887  91.479  87.536  5,79M   3,56%

# %%
plt.figure(figsize=(10,6))
plt.plot(df['Data'], df['Último'])
plt.title('Fechamento Diário da IBOVESPA')
plt.xlabel('Data')
plt.ylabel('Fechamento')
plt.grid(True)
plt.show()

# %%
df['Vol.'] = df['Vol.'].astype(str)

# %%
df['Vol.'] = df['Vol.'].str.replace('M','').str.replace(',','.').str.replace('K','').astype(float)
df['Var%'] = df['Var%'].str.replace('%','').str.replace(',','.').astype(float)

# %%
from statsmodels.tsa.stattools import adfuller

# %%
result = adfuller(df['Último'])
print('ADF Statistic:', result[0])
print('p-value:', result[1])
# Out:
# ADF Statistic: -2.4030974937872
# p-value: 0.14086407186459932

# %%
import numpy as np

# %%
plt.figure(figsize=(12,6))
correlation = df.corr()
sns.heatmap( correlation, annot=True, fmt='.2f' )
plt.title('Matriz de Correlação')
plt.show()

# %%
corr = df.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f')
# Out:
# <Axes: >

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf

# %%
from statsmodels.tsa.arima.model import ARIMA
from sklearn.model_selection import train_test_split

# %%
df.rename(columns={'Último': 'Fechamento'}, inplace=True)

# %%
result = adfuller(df['Fechamento'])
print('ADF Statistic:', result[0])
print('p-value:', result[1])
# Out:
# ADF Statistic: -2.4030974937872
# p-value: 0.14086407186459932

# %%
df.head()
# Out:
#         Data  Fechamento  Abertura   Máxima   Mínima   Vol.  Var%
# 0 2024-12-30     120.283   120.267  121.050  120.158   8.90  0.01
# 1 2024-12-27     120.269   121.078  121.609  120.252   8.94 -0.67
# 2 2024-12-26     121.078   120.767  121.612  120.428   8.34  0.26
# 3 2024-12-23     120.767   122.105  122.105  120.617   9.95 -1.09
# 4 2024-12-20     122.102   121.183  122.209  120.700  18.13  0.75

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['Data'], df['Fechamento'])
plt.title('Fechamento Diário do IBOVESPA')
plt.xlabel('Data')
plt.ylabel('Fechamento')
plt.xticks(rotation=45)
plt.show()

# %%
from scipy.stats import boxcox
import numpy as np
from scipy import stats

# %%
df['Fechamento'], lambda_ = stats.boxcox(df['Fechamento'])

# %%
df['Fechamento_boxcox'], lambda_ = stats.boxcox(df['Fechamento'])

# %%
result = sm.tsa.adfuller(df['Fechamento'])

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['Data'], df['Fechamento'])
plt.title('Fechamento Diário do IBOVESPA (Transformação de Box-Cox)')
plt.xlabel('Data')
plt.ylabel('Fechamento Transformado')
plt.xticks(rotation=45)
plt.show()

# %%
import statsmodels.api as sm

# %%
print("Estatística ADF:", resultado[0])
print("Valor p:", resultado[1])
print("Número de lags utilizados:", resultado[2])
print("Número de observações usadas para o teste:", resultado[3])
print("Valores críticos:")
for chave, valor in resultado[4].items():
        print(f'   {chave}: {valor}')
if resultado[1] < 0.05:
        print("Conclusão: A série é estacionária (rejeita-se a hipótese nula).")
else:
        print("Conclusão: A série não é estacionária (não se rejeita a hipótese nula).")
# Out:
# Estatística ADF: -2.4030974937872
# Valor p: 0.14086407186459932
# Número de lags utilizados: 8
# Número de observações usadas para o teste: 1484
# Valores críticos:
#    1%: -3.4347641828771405
#    5%: -2.863489576334964
#    10%: -2.5678079331921446
# Conclusão: A série não é estacionária (não se rejeita a hipótese nula).

# %%
df['Fechamento_boxcox'], lambda_ = stats.boxcox(df['Fechamento'])

# %%
fechamento_diff = np.diff(df['Fechamento_boxcox'], n=1)

# %%
df_diff = df.iloc[1:].copy()
df_diff['Fechamento_diff'] = fechamento_diff

# %%
plt.figure(figsize=(10, 6))
plt.plot(df_diff.index, df_diff['Fechamento_diff'])  # Agora usa o índice correto
plt.title('Fechamento Diário do IBOVESPA (Box-Cox e Diferenciação)')
plt.xlabel('Data')
plt.ylabel('Fechamento (Diferenciado)')
plt.show()

# %%
result_diff = sm.tsa.adfuller(df_diff['Fechamento_diff'].dropna())
print('ADF Statistic (Diferenciado):', result_diff[0])
print('p-value (Diferenciado):', result_diff[1])
# Out:
# ADF Statistic (Diferenciado): -12.07205207678246
# p-value (Diferenciado): 2.3355468257375715e-22

# %%
df['Fechamento']_diff = np.diff(df['Fechamento'])
 # Visualizar série diferenciada
 plt.figure(figsize=(10, 6))
 plt.plot(data.index[1:], data_boxcox_diff)
 plt.title('Fechamento Diário do IBOVESPA (Box-Cox e Diferenciação)')
 plt.xlabel('Data')
 plt.ylabel('Fechamento (Diferenciado)')
 plt.show() # Verificar estacionaridade novamente
 result_diff = sm.tsa.adfuller(data_boxcox_diff)
 print('ADF Statistic (Diferenciado):', result_diff[0])
 print('p-value (Diferenciado):', result_diff[1])
# Out:
#   File "<ipython-input-76-88af86ef994b>", line 1
#     df['Fechamento']_diff = np.diff(df['Fechamento'])
#                     ^
# SyntaxError: invalid syntax

# %%
result = sm.tsa.adfuller(data_boxcox)
print('ADF Statistic:', result[0])
print('p-value:', result[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-71-54b756f43e73> in <cell line: 1>()
# ----> 1 result = sm.tsa.adfuller(data_boxcox)
#       2 print('ADF Statistic:', result[0])
#       3 print('p-value:', result[1])
#
# NameError: name 'data_boxcox' is not defined

# %%
import matplotlib.pyplot as plt

# %%
dfdiff= df.Fechamento.diff()

# %%
dfdiff = dfdiff.dropna()

# %%
plt.figure(figsize=(10, 6))
plt.plot(dfdiff)
plt.title('Primeira Diferença')
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller

# %%
print(df.columns)
# Out:
# Index(['Data', 'Fechamento', 'Abertura', 'Máxima', 'Mínima', 'Vol.', 'Var%'], dtype='object')

# %%
resultado = adfuller(df['Fechamento'])

# %%
print("Estatística ADF:", resultado[0])
print("Valor p:", resultado[1])
print("Número de lags utilizados:", resultado[2])
print("Número de observações usadas para o teste:", resultado[3])
print("Valores críticos:")
for chave, valor in resultado[4].items():
        print(f'   {chave}: {valor}')
if resultado[1] < 0.05:
        print("Conclusão: A série é estacionária (rejeita-se a hipótese nula).")
else:
        print("Conclusão: A série não é estacionária (não se rejeita a hipótese nula).")
# Out:
# Estatística ADF: -2.4030974937872
# Valor p: 0.14086407186459932
# Número de lags utilizados: 8
# Número de observações usadas para o teste: 1484
# Valores críticos:
#    1%: -3.4347641828771405
#    5%: -2.863489576334964
#    10%: -2.5678079331921446
# Conclusão: A série não é estacionária (não se rejeita a hipótese nula).

# %%
def test_estacionarity(Fechamento):
  result = adfuller(Fechamento)

# %%
test_estacionarity(dfdiff)

# %%
print("Estatística ADF:", result[0])
print("Valor p:", result[1])
# Out:
# Estatística ADF: -2.4030974937872
# Valor p: 0.14086407186459932

# %%
temp_log = np.log(df["Fechamento"])

# %%
Fig, ax = plt.subplots()
plt.plot(temp_log)
plt.title('Segunda Diferença')
plt.show()

# %%
tem_log = np.log(df['Fechamento'])

# %%
fig,ax =plt.subplots()
ax.plot(temp_log)
plt.show()

# %%
print("Estatística ADF:", resultado[0])
print("Valor p:", resultado[1])
print("Número de lags utilizados:", resultado[2])
print("Número de observações usadas para o teste:", resultado[3])
print("Valores críticos:")
for chave, valor in resultado[4].items():
        print(f'   {chave}: {valor}')
if resultado[1] < 0.05:
        print("Conclusão: A série é estacionária (rejeita-se a hipótese nula).")
else:
        print("Conclusão: A série não é estacionária (não se rejeita a hipótese nula).")
# Out:
# Estatística ADF: -2.4030974937872
# Valor p: 0.14086407186459932
# Número de lags utilizados: 8
# Número de observações usadas para o teste: 1484
# Valores críticos:
#    1%: -3.4347641828771405
#    5%: -2.863489576334964
#    10%: -2.5678079331921446
# Conclusão: A série não é estacionária (não se rejeita a hipótese nula).

# %%
import numpy as np

# %%
tem_log = np.log(df['Fechamento'])

def test_estacionaridade(Fechamento):
    resultado = adfuller(Fechamento)

print("Estatística ADF:", resultado[0])
print("Valor p:", resultado[1])
print("Número de lags utilizados:", resultado[2])
print("Número de observações usadas para o teste:", resultado[3])
print("Valores críticos:")
for chave, valor in resultado[4].items():
        print(f'   {chave}: {valor}')
if resultado[1] < 0.05:
        print("Conclusão: A série é estacionária (rejeita-se a hipótese nula).")
else:
        print("Conclusão: A série não é estacionária (não se rejeita a hipótese nula).")
# Out:
# Estatística ADF: -2.4030974937872
# Valor p: 0.14086407186459932
# Número de lags utilizados: 8
# Número de observações usadas para o teste: 1484
# Valores críticos:
#    1%: -3.4347641828771405
#    5%: -2.863489576334964
#    10%: -2.5678079331921446
# Conclusão: A série não é estacionária (não se rejeita a hipótese nula).

# %%
test_estacionaridade(tem_log)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-1eaff24be5ae> in <cell line: 2>()
#       1 plt.figure(figsize=(10, 6))
# ----> 2 plt.plot(Data)
#       3 plt.title('Fechamento Diário do IBOVESPA')
#       4 plt.xlabel('Data')
#       5 plt.ylabel('ultimo')
#
# NameError: name 'Data' is not defined

# %%
ehEstacionaria(tem_log)

# %%
seasonality = 10 * np.sin(np.linspace(0, 3.14*2, 60))

# %%
noise = np.random.normal(0, 5, 60)
data = trend + seasonality + noise
df = pd.DataFrame(data, columns=['Data'], index=time)

# %%
plt.figure(figsize=(10, 6))
plot_acf(df['Data'], lags=20)
plt.title('Gráfico de Autocorrelação (ACF)')
plt.show()

# %%
df.head()

# %%
df = df.dropna()
